# %% [markdown]
# # 描述性统计

# %%
import numpy as np
import pandas as pd

# %%
path='D:\\01study\\01 大三\\python\\大作业\\数据及说明\\原微博样本.csv'
DfData = pd.read_csv(path, encoding='utf-8',  low_memory=False)

DfData.describe()
# Out:
#                  序号           粉丝数            微博数              转  \
# count  664090.00000  6.640900e+05  664090.000000  664090.000000
# mean   332045.50000  1.535910e+06   66197.331556      14.135744
# std    191706.41447  3.408257e+06   70810.487667     581.429565
# min         1.00000  0.000000e+00       0.000000       0.000000
# 25%    166023.25000  1.511000e+04   17681.000000       0.000000
# 50%    332045.50000  3.544650e+05   43631.000000       0.000000
# 75%    498067.75000  1.557031e+06   95308.000000       3.000000
# max    664090.00000  1.978622e+07  498689.000000  185808.000000
#
#                    评             赞
# count  664090.000000  6.640900e+05
# mean       11.476053  1.169366e+02
# std       211.350211  5.008357e+03
# min         0.000000  0.000000e+00
# 25%         0.000000  0.000000e+00
# 50%         0.000000  1.000000e+00
# 75%         3.000000  8.000000e+00
# max     71628.000000  2.203895e+06

# %% [markdown]
# # 相关性画图+相关系数

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib
Select_cols=['粉丝数','微博数','转','评','赞']
Select_df=DfData[Select_cols]

Select_df.corr()
# Out:
#           粉丝数       微博数         转         评         赞
# 粉丝数  1.000000  0.306236  0.006641  0.026848  0.022120
# 微博数  0.306236  1.000000 -0.001073 -0.006359 -0.000861
# 转    0.006641 -0.001073  1.000000  0.415313  0.312666
# 评    0.026848 -0.006359  0.415313  1.000000  0.800174
# 赞    0.022120 -0.000861  0.312666  0.800174  1.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib
path='D:\\01study\\01 大三\\python\\大作业\\数据及说明\\原微博样本.csv'
DfData = pd.read_csv(path, encoding='utf-8',  low_memory=False)
Select_cols=['粉丝数','微博数','转','评','赞']
Select_df=DfData[Select_cols]
matplotlib.rcParams['font.sans-serif'] = ['KaiTi']
sns.pairplot(DfData , hue ='性别')
#设置字体为楷体

# %%
sns.heatmap(DfData.corr())
# Out:
# <AxesSubplot:>
